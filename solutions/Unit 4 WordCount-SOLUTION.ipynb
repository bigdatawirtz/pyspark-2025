# %% [markdown]
# # WordCount

# %% [markdown]
# ## Load data

# %%
lines = sc.textFile('datasets/slurmd/slurmd.log.c6601')

# %%
lines.take(5)
# Out:
# [u'1482336831 2016 Dec 21 17:13:51 c6601 daemon info slurmd launch task 387796.0 request from 10946.113@10.118.68.11 (port 42900)',
#  u'1482336831 2016 Dec 21 17:13:51 c6601 daemon err slurmd error: gres/mic unable to set OFFLOAD_DEVICES, no device files configured',
#  u'1482336831 2016 Dec 21 17:13:51 c6601 daemon info slurmd _run_prolog: run job script took usec=60615',
#  u'1482336831 2016 Dec 21 17:13:51 c6601 daemon info slurmd _run_prolog: prolog with lock for job 387796 ran for 0 seconds',
#  u'1482336899 2016 Dec 21 17:14:59 c6601 daemon info slurmd launch task 387797.0 request from 10946.113@10.118.68.11 (port 62868)']

# %% [markdown]
# ## Split lines into words

# %%
words = lines.flatMap(lambda line: line.split())

# %%
words.take(5)
# Out:
# [u'1482336831', u'2016', u'Dec', u'21', u'17:13:51']

# %% [markdown]
# ## Transform in a Pair RDD: word -> (word, 1)

# %%
counts = words.map(lambda word: (word,1))

# %%
counts.take(5)
# Out:
# [(u'1482336831', 1), (u'2016', 1), (u'Dec', 1), (u'21', 1), (u'17:13:51', 1)]

# %% [markdown]
# ## Aggregate counts

# %%
aggregated = counts.reduceByKey(lambda x, y: x+y)

# %%
aggregated.take(5)
# Out:
# [(u'11:59:51', 8),
#  (u'531335', 1),
#  (u'750633', 1),
#  (u'47233)', 1),
#  (u'11:55:35', 1)]

# %% [markdown]
# ## Show the 10 most common words

# %% [markdown]
# Invert the tuple contents so that the key is the number of occurrences

# %%
result = aggregated.map(lambda (a, b): (b,a))

# %%
result.take(5)
# Out:
# [(8, u'11:59:51'),
#  (1, u'3986)'),
#  (8, u'11:59:55'),
#  (1, u'47233)'),
#  (1, u'/slurm/uid_10795/job_392998/step_0:')]

# %% [markdown]
# Sort and take the 10 first elements:

# %%
result.sortByKey(ascending=False).take(10)
